# %%
from __future__ import print_function

# %matplotlib inline


import numpy as np
import pysptools.util as util
import pysptools.eea as eea
import pysptools.abundance_maps as amp
import os
import os.path as osp
import spectral.io.envi as envi
import matplotlib.pyplot as plt
import pysptools.classification as cls
from spectral import *

import pysptools.material_count as cnt
import pysptools.spectro as spectro
import scipy
import scipy.io

# %% [markdown]
# # EE Algorithms \& Abundance Map \& Load ICA Dataset

# %%
def get_endmembers_NFINDR(data):
    print('Endmembers extraction with NFINDR')
    nfindr = eea.NFINDR()
    U = nfindr.extract(data, 7, maxit=10, normalize=True, ATGP_init=True)
    # 7 is the EM we want to find

    nfindr.display() # suffix='Forest-Original')
    # return an array of endmembers
    return U
def get_endmembers_ATGP(data):
    print('Endmembers extraction with ATGP')
    atgp = eea.ATGP()
    U = atgp.extract(data, 7, normalize=True)
    # 7 is the EM we want to find

    atgp.display() # display(suffix='Forest-Original')
    # return an array of endmembers
    return U
def get_endmembers_FIPPI(data):
    print('Endmembers extraction with FIPPI')
    fippi = eea.FIPPI()
    U = fippi.extract(data, 7, normalize=True)
    # 7 is the EM we want to find

    fippi.display() # (suffix='Forest-Original')
    # return an array of endmembers
    return U
def gen_abundance_maps(data, U):
    print('Abundance maps generation with NNLS')
    nnls = amp.NNLS()
    amaps = nnls.map(data, U, normalize=True)
    nnls.display(colorMap='jet', columns=7) #, suffix='Forest Abundance Map using NFINDR Result')
    # return a cube of abundance maps
    return amaps

# %%
ica_den = scipy.io.loadmat('ica_den.mat')
ica_den = ica_den['ica_den']

# %% [markdown]
# # Endmembers from ICA denoised dataset

# %%
# ATGP
icad_atgp = get_endmembers_ATGP(ica_den)
ida_am = gen_abundance_maps(ica_den, icad_atgp)
icad_atgp = {"icad_atgp": icad_atgp}
scipy.io.savemat("icad_atgp.mat", icad_atgp)
# Out:
# Endmembers extraction with ATGP
# Abundance maps generation with NNLS
# /Users/ckn/opt/anaconda3/lib/python3.8/site-packages/pysptools/abundance_maps/amaps_int.py:127: UserWarning: In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns
#   warnings.warn('In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns')

# %%
# N-Finder
icad_nfindr = get_endmembers_NFINDR(ica_den)
idn_am = gen_abundance_maps(ica_den, icad_nfindr)
icad_nfindr = {"icad_nfindr": icad_nfindr}
scipy.io.savemat("icad_nfindr.mat", icad_nfindr)
# Out:
# Endmembers extraction with NFINDR
# Abundance maps generation with NNLS
# /Users/ckn/opt/anaconda3/lib/python3.8/site-packages/pysptools/abundance_maps/amaps_int.py:127: UserWarning: In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns
#   warnings.warn('In abundance_map._plot_abundance_map, the number of abundances map to display is less or equal the number of columns')

# %%
icad_atgp = scipy.io.loadmat('icad_atgp.mat')
icad_atgp = icad_atgp['icad_atgp']

plt.figure(figsize=(10,6))
sub_axix = filter(lambda x:x%200 == 0, range(1,373))
# plt.title('Spectral profiles')
plt.plot(range(1,373), icad_atgp[0,:], color='burlywood', label='Endmember1')
plt.plot(range(1,373), icad_atgp[1,:], color='green', label='Endmember2')
plt.plot(range(1,373), icad_atgp[2,:], color='red', label='Endmember3')
plt.plot(range(1,373), icad_atgp[3,:], color='skyblue', label='Endmember4')
plt.plot(range(1,373), icad_atgp[4,:], color='blue', label='Endmember5')
plt.plot(range(1,373), icad_atgp[5,:], color='cyan', label='Endmember6')
plt.plot(range(1,373), icad_atgp[6,:], color='magenta', label='Endmember7')


plt.legend() # 显示图例

plt.xlabel('spectral bands')
#plt.ylabel('reflectance')
plt.show()

# %%
icad_nfindr = scipy.io.loadmat('icad_nfindr.mat')
icad_nfindr = icad_nfindr['icad_nfindr']

plt.figure(figsize=(10,6))
sub_axix = filter(lambda x:x%200 == 0, range(1,373))
# plt.title('Spectral profiles')
plt.plot(range(1,373), icad_nfindr[6,:], color='burlywood', label='Endmember1')
plt.plot(range(1,373), icad_nfindr[2,:], color='green', label='Endmember2')
plt.plot(range(1,373), icad_nfindr[1,:], color='red', label='Endmember3')
plt.plot(range(1,373), icad_nfindr[0,:], color='skyblue', label='Endmember4')
plt.plot(range(1,373), icad_nfindr[4,:], color='blue', label='Endmember5')
plt.plot(range(1,373), icad_nfindr[3,:], color='cyan', label='Endmember6')
plt.plot(range(1,373), icad_nfindr[5,:], color='magenta', label='Endmember7')


plt.legend() # 显示图例

plt.xlabel('spectral bands')
#plt.ylabel('reflectance')
plt.show()

# %%
icad_atgp = scipy.io.loadmat('icad_atgp.mat')
icad_atgp = icad_atgp['icad_atgp']

plt.figure(figsize=(4,2))
sub_axix = filter(lambda x:x%200 == 0, range(1,373))
# plt.title('Spectral profiles')
plt.plot(range(1,373), icad_atgp[0,:], color='burlywood', label='Endmember1')
plt.plot(range(1,373), icad_atgp[1,:], color='green', label='Endmember2')
plt.plot(range(1,373), icad_atgp[2,:], color='red', label='Endmember3')
plt.plot(range(1,373), icad_atgp[3,:], color='skyblue', label='Endmember4')
plt.plot(range(1,373), icad_atgp[4,:], color='blue', label='Endmember5')
plt.plot(range(1,373), icad_atgp[5,:], color='cyan', label='Endmember6')
plt.plot(range(1,373), icad_atgp[6,:], color='magenta', label='Endmember7')


# plt.legend() # 显示图例

plt.xlabel('spectral bands')
#plt.ylabel('reflectance')
plt.show()

# %%
icad_nfindr = scipy.io.loadmat('icad_nfindr.mat')
icad_nfindr = icad_nfindr['icad_nfindr']

plt.figure(figsize=(4,2))
sub_axix = filter(lambda x:x%200 == 0, range(1,373))
# plt.title('Spectral profiles')
plt.plot(range(1,373), icad_nfindr[6,:], color='burlywood', label='Endmember1')
plt.plot(range(1,373), icad_nfindr[2,:], color='green', label='Endmember2')
plt.plot(range(1,373), icad_nfindr[1,:], color='red', label='Endmember3')
plt.plot(range(1,373), icad_nfindr[0,:], color='skyblue', label='Endmember4')
plt.plot(range(1,373), icad_nfindr[4,:], color='blue', label='Endmember5')
plt.plot(range(1,373), icad_nfindr[3,:], color='cyan', label='Endmember6')
plt.plot(range(1,373), icad_nfindr[5,:], color='magenta', label='Endmember7')


#plt.legend() # 显示图例

#plt.xlabel('spectral bands')
#plt.ylabel('reflectance')
plt.show()
